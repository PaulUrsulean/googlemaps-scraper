# %% [markdown]
# ### Requirements
#
# `
# sudo apt-get install -y chromium-browser chromium-chromedriver xdg-utils
# sudo apt-get install -y libglib2.0-0 libnss3 libgconf-2-4 libfontconfig1 #not sure if these are necessary
# conda create --name scraping python=3.6 --file requirements.txt
# conda activate scraping
# `

# %%
# !python scraper.py --N 20
# Out:
# Fetching reviews: 20it [00:06,  3.12it/s]

# %%
import pandas as pd
pd.read_csv("data/gm_reviews.csv")
# Out:
#                                id_review  \
# 0   ChdDSUhNMG9nS0VJQ0FnSUM4cVpyajV3RRAB
# 1   ChdDSUhNMG9nS0VJQ0FnSUM4cWNLQTRRRRAB
# 2   ChdDSUhNMG9nS0VJQ0FnSUM4cWJEa253RRAB
# 3    ChZDSUhNMG9nS0VJQ0FnSURzbXNhckpBEAE
# 4   ChdDSUhNMG9nS0VJQ0FnSUM4eWNPTHB3RRAB
# 5   ChdDSUhNMG9nS0VJQ0FnSUM4eVpueTJBRRAB
# 6    ChZDSUhNMG9nS0VJQ0FnSUM4eVphNEJnEAE
# 7    ChZDSUhNMG9nS0VJQ0FnSUM4eWNyN1NREAE
# 8    ChZDSUhNMG9nS0VJQ0FnSUM4eWNxTVp3EAE
# 9   ChdDSUhNMG9nS0VJQ0FnSUM4aVluUjFnRRAB
# 10   ChZDSUhNMG9nS0VJQ0FnSUM4OGY2ZkpBEAE
# 11   ChZDSUhNMG9nS0VJQ0FnSUM4a1lPYWV3EAE
# 12   ChZDSUhNMG9nS0VJQ0FnSUM4NGIyZ1Z3EAE
# 13   ChZDSUhNMG9nS0VJQ0FnSUM4b2FYSWJREAE
# 14   ChZDSUhNMG9nS0VJQ0FnSUM4b2ZIOE53EAE
# 15   ChZDSUhNMG9nS0VJQ0FnSUM4b2JxdFhnEAE
# 16  ChdDSUhNMG9nS0VJQ0FnSUM4b2F6ajNRRRAB
# 17   ChZDSUhNMG9nS0VJQ0FnSUM4b1pUSGZ3EAE
# 18   ChZDSUhNMG9nS0VJQ0FnSUM4d2VuY0NBEAE
# 19  ChdDSUhNMG9nS0VJQ0FnSUM4d1pDMG9RRRAB
#
#                                               caption  rating  \
# ...
